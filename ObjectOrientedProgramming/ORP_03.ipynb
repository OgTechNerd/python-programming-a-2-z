# %% [markdown]
# # **Object Oriented Programming**

# %% [markdown]
# ## **Topics Covered :**
#
# + Class vs Object
# + Constructor
# + Class Variables vs Instance Variable

# %% [markdown]
# Example of a class with instance method
# Instance variables: The instance variable’s value varies from object to object. Objects do not share instance variables. Every object has its copy of the instance attribute.
# Class Variables: A class variable is a variable that is declared inside of a class but outside of any instance method or init() method. Class variables are shared by all instances of a class.
# A class method is a method that is bound to the class and not the object of the class. They have the access to the state of the class as it takes a class parameter that points to the class and not the object instance. It can modify a class state that would apply across all the instances of the class. For example, it can modify a class variable that will be applicable to all the instances.

# %%
class GenericMissile:
    def __init__(self, type:str, make:str, cost: int) -> None:
        self.type = type
        self.make = make
        self.cost = cost
        
    def getErrorRate(self, obsrv_val:int, act_val:int):
        errRate = (obsrv_val - act_val)/act_val * 100
        return errRate
    
    def getAccuracy(self, errRate):
        acc = 100 - errRate 
        print(f"Accuracy Rate of this missile is {acc}")

brahmos_missile = GenericMissile('BalasticMissile', 'Indian', '5000000000')
error_rate=brahmos_missile.getErrorRate(10, 9)
print(f"Error Rate of this Missile is {error_rate}")
brahmos_missile.getAccuracy(error_rate)
# Out:
# Error Rate of this Missile is 11.11111111111111
# Accuracy Rate of this missile is 88.88888888888889

# %%
from datetime import datetime
class Employee:
    empType = 'permanent'
    empStatus = 'retained'
    
    def __init__(self, name, age, sex, dept):
        self.name = name
        self.age = age
        self.sex = sex
        self.dept = dept
    def getExperience(doj):
        pass
    def getAppraisal(sal, hike):
        pass
    """
    The @classmethod decorator is a built-in function decorator that is an expression that gets evaluated 
    after your function is defined. The result of that evaluation shadows your function definition.
    A class method receives the class as an implicit first argument, just like an instance method receives the instance 
    """
    
    @classmethod 
    def changeEmpAttr(cls, type=str, stat=str):
        cls.empType = type
        cls.empStatus = stat
        
    """What is the Static Method in Python?
    A static method does not receive an implicit first argument. A static method is also a method that is bound to the class 
    and not the object of the class. This method can’t access or modify the class state. It is present in a class because it
    makes sense for the method to be present in class.
    """
    @staticmethod
    def checkAgeAndSex(age , sex):
        if (age)
        
        
akash = Employee('akash', 32, 'Male', 'Engg')
print(f"Employee Attributes changed to {Employee.empType} and {Employee.empStatus}")
akash.changeEmpAttr('contract', 'fired')
print(f"Employee Attributes changed to {Employee.empType} and {Employee.empStatus}")
# Out:
# Employee Attributes changed to permanent and retained
# Employee Attributes changed to contract and fired
